# %%
import pandas as pd
#load
df = pd.read_csv('../data/raw/ecommerce.csv', encoding='latin1')

# %%
import os
print(os.getcwd())
print(os.listdir('.'))      # files in current folder
print(os.listdir('data/raw') if os.path.exists('data/raw') else "data/raw doesn't exist")
# Out:
# c:\projects\ecommerce-analytics-pipeline\notebooks
# ['exploratory_analysis.ipynb']
# data/raw doesn't exist

# %%
# Understand
print(f"Shape: {df.shape}")
print(f"Columns: {df.columns.tolist()}")
print(f"Dtypes:\n{df.dtypes}")
print(f"Missing:\n{df.isnull().sum()}")
print(f"Duplicates: {df.duplicated().sum()}")
# Out:
# Shape: (541909, 8)
# Columns: ['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate', 'UnitPrice', 'CustomerID', 'Country']
# Dtypes:
# InvoiceNo       object
# StockCode       object
# Description     object
# Quantity         int64
# InvoiceDate     object
# UnitPrice      float64
# CustomerID     float64
# Country         object
# dtype: object
# Missing:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64
# Duplicates: 5268

# %%
# Key metrics
print(f"Date range: {df['InvoiceDate'].min()} to {df['InvoiceDate'].max()}")
print(f"Unique customers: {df['CustomerID'].nunique()}")
print(f"Unique products: {df['StockCode'].nunique()}")
print(f"Countries: {df['Country'].nunique()}")
# Out:
# Date range: 1/10/2011 10:04 to 9/9/2011 9:52
# Unique customers: 4372
# Unique products: 4070
# Countries: 38
